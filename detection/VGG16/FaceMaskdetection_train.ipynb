# %%
# from google.colab import drive

# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import the necessary packages

from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from imutils import paths

import matplotlib.pyplot as plt
import numpy as np
import pickle
import cv2
import os

print("All modules are imported")
# Out:
# All modules are imported

# %%
# import the necessary packages
import os

# define the base path to the input dataset and then use it to derive
# the path to the input images and annotation CSV files
BASE_PATH = "dataset"
IMAGES_PATH = os.path.sep.join([BASE_PATH, "images"])
ANNOTS_PATH = os.path.sep.join([BASE_PATH, "annotations"])

# %%
# initialize the list of data (images), class labels, target bounding
# box coordinates, and image paths
print("[INFO] loading dataset...")
data = []
labels = []
bboxes = []
imagePaths = []
# Out:
# [INFO] loading dataset...

# %%
print(ANNOTS_PATH)
# Out:
# dataset/annotations

# %%
# loop over all CSV files in the annotations directory
for csvPath in paths.list_files(ANNOTS_PATH, validExts=(".csv")):
    print("here")
    # load the contents of the current CSV annotations file
    rows = open(csvPath).read().strip().split("\n")
    
    # loop over the rows 
    for row in rows:
        # break the row into the filename, bounding box coordinates,
        # and class label
        row = row.split(",")
        (filename, startX, startY, endX, endY, label) = row
        
        # derive the path to the input image, load the image (in
        # OpenCV format), and grab its dimensions
        imagePath = os.path.sep.join([IMAGES_PATH, label, filename])
        # print(imagePath)

        image = cv2.imread(imagePath)
        (h, w) = image.shape[:2]
        
        # scale the bounding box coordinates relative to the spatial
        # dimensions of the input image
        startX = float(startX) / w
        startY = float(startY) / h
        endX = float(endX) / w
        endY = float(endY) / h
        
        # load the image and preprocess it
        image = load_img(imagePath, target_size=(224, 224))
        image = img_to_array(image)
        # update our list of data, class labels, bounding boxes, and
        # image paths
        data.append(image)
        labels.append(label)
        bboxes.append((startX, startY, endX, endY))
        imagePaths.append(imagePath)
# Out:
# here
# here
# here

# %%
# initialize our initial learning rate, number of epochs to train
# for, and the batch size
INIT_LR = 1e-4
NUM_EPOCHS = 200
BATCH_SIZE = 128

# define the path to the base output directory
BASE_OUTPUT = "output"
# define the path to the output model, label binarizer, plots output
# directory, and testing image paths

model_name = "detector_bt_" + str(BATCH_SIZE) + "_ep_" + str(NUM_EPOCHS) + ".h5"
MODEL_PATH = os.path.sep.join([BASE_OUTPUT, model_name])

pickle_name = "lb_bt_" + str(BATCH_SIZE) + "_ep_" + str(NUM_EPOCHS) + ".pickle"
LB_PATH = os.path.sep.join([BASE_OUTPUT, pickle_name])

PLOTS_PATH = os.path.sep.join([BASE_OUTPUT, "plots"])
TEST_PATHS = os.path.sep.join([BASE_OUTPUT, "test_paths.txt"])

# %%
# convert the data, class labels, bounding boxes, and image paths to
# NumPy arrays, scaling the input pixel intensities from the range
# [0, 255] to [0, 1]
data = np.array(data, dtype="float32") / 255.0
labels = np.array(labels)
bboxes = np.array(bboxes, dtype="float32")
imagePaths = np.array(imagePaths)

# perform one-hot encoding on the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# only there are only two labels in the dataset, then we need to use
# Keras/TensorFlow's utility function as well
if len(lb.classes_) == 2:
  labels = to_categorical(labels)
  
# partition the data into training and testing splits using 80% of
# the data for training and the remaining 20% for testing
split = train_test_split(data, labels, bboxes, imagePaths,
  test_size=0.20, random_state=42)

# unpack the data split
(trainImages, testImages) = split[:2]
(trainLabels, testLabels) = split[2:4]
(trainBBoxes, testBBoxes) = split[4:6]
(trainPaths, testPaths) = split[6:]

# write the testing image paths to disk so that we can use then
# when evaluating/testing our object detector
print("[INFO] saving testing image paths...")
f = open(TEST_PATHS, "w")
f.write("\n".join(testPaths))
f.close()

# load the VGG16 network, ensuring the head FC layers are left off
vgg = VGG16(weights="imagenet", include_top=False,
  input_tensor=Input(shape=(224, 224, 3)))

# freeze all VGG layers so they will *not* be updated during the
# training process
vgg.trainable = False

# flatten the max-pooling output of VGG
flatten = vgg.output
flatten = Flatten()(flatten)

# construct a fully-connected layer header to output the predicted
# bounding box coordinates
bboxHead = Dense(128, activation="relu")(flatten)
bboxHead = Dense(64, activation="relu")(bboxHead)
bboxHead = Dense(32, activation="relu")(bboxHead)
bboxHead = Dense(4, activation="sigmoid",
  name="bounding_box")(bboxHead)

# construct a second fully-connected layer head, this one to predict
# the class label
softmaxHead = Dense(512, activation="relu")(flatten)
softmaxHead = Dropout(0.5)(softmaxHead)
softmaxHead = Dense(512, activation="relu")(softmaxHead)
softmaxHead = Dropout(0.5)(softmaxHead)
softmaxHead = Dense(len(lb.classes_), activation="softmax",
  name="class_label")(softmaxHead)

# put together our model which accept an input image and then output
# bounding box coordinates and a class label
model = Model(
  inputs=vgg.input,
  outputs=(bboxHead, softmaxHead))

# define a dictionary to set the loss methods -- categorical
# cross-entropy for the class label head and mean absolute error
# for the bounding box head
losses = {
  "class_label": "categorical_crossentropy",
  "bounding_box": "mean_squared_error",
}

# define a dictionary that specifies the weights per loss (both the
# class label and bounding box outputs will receive equal weight)
lossWeights = {
  "class_label": 1.0,
  "bounding_box": 1.0
}

# initialize the optimizer, compile the model, and show the model
# summary
opt = Adam(lr=INIT_LR)
model.compile(loss=losses, optimizer=opt, metrics=["accuracy"], loss_weights=lossWeights)
print(model.summary())

# construct a dictionary for our target training outputs
trainTargets = {
  "class_label": trainLabels,
  "bounding_box": trainBBoxes
}

# construct a second dictionary, this one for our target testing
# outputs
testTargets = {
  "class_label": testLabels,
  "bounding_box": testBBoxes
}

# train the network for bounding box regression and class label
# prediction
print("[INFO] training model...")
H = model.fit(
  trainImages, trainTargets,
  validation_data=(testImages, testTargets),
  batch_size=BATCH_SIZE,
  epochs=NUM_EPOCHS,
  verbose=1)

# serialize the model to disk
print("[INFO] saving object detector model...")
model.save(MODEL_PATH, save_format="h5")

# serialize the label binarizer to disk
print("[INFO] saving label binarizer...")
f = open(LB_PATH, "wb")
f.write(pickle.dumps(lb))
f.close()

# plot the total loss, label loss, and bounding box loss
lossNames = ["loss", "class_label_loss", "bounding_box_loss"]
N = np.arange(0, NUM_EPOCHS)
plt.style.use("ggplot")
(fig, ax) = plt.subplots(3, 1, figsize=(13, 13))

# loop over the loss names
for (i, l) in enumerate(lossNames):
  # plot the loss for both the training and validation data
  title = "Loss for {}".format(l) if l != "loss" else "Total loss"
  ax[i].set_title(title)
  ax[i].set_xlabel("Epoch #")
  ax[i].set_ylabel("Loss")
  ax[i].plot(N, H.history[l], label=l)
  ax[i].plot(N, H.history["val_" + l], label="val_" + l)
  ax[i].legend()
  
# save the losses figure and create a new figure for the accuracies
plt.tight_layout()

loss_path = "losses_" + str(BATCH_SIZE) + "_ep_" + str(NUM_EPOCHS) + ".png"
plotPath = os.path.sep.join([PLOTS_PATH, loss_path])
plt.savefig(plotPath)
plt.close()

# create a new figure for the accuracies
plt.style.use("ggplot")
plt.figure()
plt.plot(N, H.history["class_label_accuracy"],
  label="class_label_train_acc")
plt.plot(N, H.history["val_class_label_accuracy"],
  label="val_class_label_acc")
plt.title("Class Label Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend(loc="lower left")

# save the accuracies plot
acc_path = "accs_" + str(BATCH_SIZE) + "_ep_" + str(NUM_EPOCHS) + ".png"
plotPath = os.path.sep.join([PLOTS_PATH, acc_path])
plt.savefig(plotPath)

print("Training Done")
# Out:
# [INFO] saving testing image paths...
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 224, 224, 64) 1792        input_7[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 224, 224, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 112, 112, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 112, 112, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 112, 112, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 56, 56, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 56, 56, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 28, 28, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 28, 28, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 14, 14, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 14, 14, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 7, 7, 512)    0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 25088)        0           block5_pool[0][0]
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 512)          12845568    flatten_6[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 128)          3211392     flatten_6[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 512)          0           dense_33[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 64)           8256        dense_30[0][0]
# __________________________________________________________________________________________________
# dense_34 (Dense)                (None, 512)          262656      dropout_12[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 32)           2080        dense_31[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 512)          0           dense_34[0][0]
# __________________________________________________________________________________________________
# bounding_box (Dense)            (None, 4)            132         dense_32[0][0]
# __________________________________________________________________________________________________
# class_label (Dense)             (None, 3)            1539        dropout_13[0][0]
# ==================================================================================================
# Total params: 31,046,311
# Trainable params: 16,331,623
# Non-trainable params: 14,714,688
# __________________________________________________________________________________________________
# None
# [INFO] training model...
# Epoch 1/200
# 26/26 [==============================] - 9s 312ms/step - loss: 0.8356 - bounding_box_loss: 0.0527 - class_label_loss: 0.7829 - bounding_box_accuracy: 0.5848 - class_label_accuracy: 0.7313 - val_loss: 0.7000 - val_bounding_box_loss: 0.0514 - val_class_label_loss: 0.6486 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 2/200
# 26/26 [==============================] - 8s 297ms/step - loss: 0.6830 - bounding_box_loss: 0.0510 - class_label_loss: 0.6320 - bounding_box_accuracy: 0.6362 - class_label_accuracy: 0.7877 - val_loss: 0.6953 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6445 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 3/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6628 - bounding_box_loss: 0.0521 - class_label_loss: 0.6108 - bounding_box_accuracy: 0.6287 - class_label_accuracy: 0.7979 - val_loss: 0.6964 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6456 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 4/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.7010 - bounding_box_loss: 0.0512 - class_label_loss: 0.6498 - bounding_box_accuracy: 0.6239 - class_label_accuracy: 0.7904 - val_loss: 0.6963 - val_bounding_box_loss: 0.0512 - val_class_label_loss: 0.6451 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 5/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6620 - bounding_box_loss: 0.0511 - class_label_loss: 0.6109 - bounding_box_accuracy: 0.6233 - class_label_accuracy: 0.8034 - val_loss: 0.6981 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6473 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 6/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6648 - bounding_box_loss: 0.0508 - class_label_loss: 0.6141 - bounding_box_accuracy: 0.6509 - class_label_accuracy: 0.8042 - val_loss: 0.6987 - val_bounding_box_loss: 0.0511 - val_class_label_loss: 0.6477 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 7/200
# 26/26 [==============================] - 8s 297ms/step - loss: 0.6470 - bounding_box_loss: 0.0508 - class_label_loss: 0.5962 - bounding_box_accuracy: 0.6220 - class_label_accuracy: 0.8033 - val_loss: 0.6971 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6462 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 8/200
# 26/26 [==============================] - 8s 295ms/step - loss: 0.6662 - bounding_box_loss: 0.0517 - class_label_loss: 0.6145 - bounding_box_accuracy: 0.6270 - class_label_accuracy: 0.7968 - val_loss: 0.6958 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6448 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 9/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6340 - bounding_box_loss: 0.0506 - class_label_loss: 0.5834 - bounding_box_accuracy: 0.6212 - class_label_accuracy: 0.8100 - val_loss: 0.6962 - val_bounding_box_loss: 0.0512 - val_class_label_loss: 0.6450 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 10/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6671 - bounding_box_loss: 0.0510 - class_label_loss: 0.6161 - bounding_box_accuracy: 0.6403 - class_label_accuracy: 0.7964 - val_loss: 0.7055 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6545 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 11/200
# 26/26 [==============================] - 8s 300ms/step - loss: 0.6568 - bounding_box_loss: 0.0509 - class_label_loss: 0.6059 - bounding_box_accuracy: 0.6186 - class_label_accuracy: 0.7971 - val_loss: 0.6986 - val_bounding_box_loss: 0.0511 - val_class_label_loss: 0.6476 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 12/200
# 26/26 [==============================] - 8s 296ms/step - loss: 0.6630 - bounding_box_loss: 0.0520 - class_label_loss: 0.6110 - bounding_box_accuracy: 0.6214 - class_label_accuracy: 0.7966 - val_loss: 0.6952 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6445 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 13/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6888 - bounding_box_loss: 0.0521 - class_label_loss: 0.6367 - bounding_box_accuracy: 0.6244 - class_label_accuracy: 0.7851 - val_loss: 0.6981 - val_bounding_box_loss: 0.0510 - val_class_label_loss: 0.6471 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 14/200
# 26/26 [==============================] - 8s 297ms/step - loss: 0.6396 - bounding_box_loss: 0.0506 - class_label_loss: 0.5890 - bounding_box_accuracy: 0.6368 - class_label_accuracy: 0.8026 - val_loss: 0.6985 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6476 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 15/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6628 - bounding_box_loss: 0.0519 - class_label_loss: 0.6109 - bounding_box_accuracy: 0.6265 - class_label_accuracy: 0.7962 - val_loss: 0.6973 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6465 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 16/200
# 26/26 [==============================] - 8s 296ms/step - loss: 0.6448 - bounding_box_loss: 0.0512 - class_label_loss: 0.5936 - bounding_box_accuracy: 0.6166 - class_label_accuracy: 0.8065 - val_loss: 0.7095 - val_bounding_box_loss: 0.0520 - val_class_label_loss: 0.6575 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 17/200
# 26/26 [==============================] - 8s 297ms/step - loss: 0.6721 - bounding_box_loss: 0.0515 - class_label_loss: 0.6207 - bounding_box_accuracy: 0.6273 - class_label_accuracy: 0.7918 - val_loss: 0.6961 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6453 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 18/200
# 26/26 [==============================] - 8s 297ms/step - loss: 0.6564 - bounding_box_loss: 0.0520 - class_label_loss: 0.6044 - bounding_box_accuracy: 0.6262 - class_label_accuracy: 0.8044 - val_loss: 0.6972 - val_bounding_box_loss: 0.0513 - val_class_label_loss: 0.6459 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 19/200
# 26/26 [==============================] - 8s 297ms/step - loss: 0.6509 - bounding_box_loss: 0.0501 - class_label_loss: 0.6008 - bounding_box_accuracy: 0.6150 - class_label_accuracy: 0.8013 - val_loss: 0.6995 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6486 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 20/200
# 26/26 [==============================] - 8s 296ms/step - loss: 0.6393 - bounding_box_loss: 0.0517 - class_label_loss: 0.5877 - bounding_box_accuracy: 0.6256 - class_label_accuracy: 0.8064 - val_loss: 0.7194 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6686 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 21/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6696 - bounding_box_loss: 0.0509 - class_label_loss: 0.6187 - bounding_box_accuracy: 0.6196 - class_label_accuracy: 0.7970 - val_loss: 0.7027 - val_bounding_box_loss: 0.0510 - val_class_label_loss: 0.6516 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 22/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6892 - bounding_box_loss: 0.0519 - class_label_loss: 0.6373 - bounding_box_accuracy: 0.6345 - class_label_accuracy: 0.7812 - val_loss: 0.7032 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6523 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 23/200
# 26/26 [==============================] - 8s 297ms/step - loss: 0.6800 - bounding_box_loss: 0.0499 - class_label_loss: 0.6301 - bounding_box_accuracy: 0.6353 - class_label_accuracy: 0.7942 - val_loss: 0.7032 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6524 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 24/200
# 26/26 [==============================] - 8s 296ms/step - loss: 0.6744 - bounding_box_loss: 0.0519 - class_label_loss: 0.6225 - bounding_box_accuracy: 0.6153 - class_label_accuracy: 0.7980 - val_loss: 0.7047 - val_bounding_box_loss: 0.0510 - val_class_label_loss: 0.6537 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 25/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6618 - bounding_box_loss: 0.0506 - class_label_loss: 0.6112 - bounding_box_accuracy: 0.6406 - class_label_accuracy: 0.7949 - val_loss: 0.7029 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6520 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 26/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6649 - bounding_box_loss: 0.0518 - class_label_loss: 0.6131 - bounding_box_accuracy: 0.6357 - class_label_accuracy: 0.7980 - val_loss: 0.7063 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6556 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 27/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6610 - bounding_box_loss: 0.0521 - class_label_loss: 0.6089 - bounding_box_accuracy: 0.6212 - class_label_accuracy: 0.7987 - val_loss: 0.7017 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6509 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 28/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6603 - bounding_box_loss: 0.0517 - class_label_loss: 0.6085 - bounding_box_accuracy: 0.6415 - class_label_accuracy: 0.7966 - val_loss: 0.7069 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6562 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 29/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6582 - bounding_box_loss: 0.0522 - class_label_loss: 0.6059 - bounding_box_accuracy: 0.6201 - class_label_accuracy: 0.7963 - val_loss: 0.7100 - val_bounding_box_loss: 0.0513 - val_class_label_loss: 0.6587 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 30/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6470 - bounding_box_loss: 0.0505 - class_label_loss: 0.5965 - bounding_box_accuracy: 0.6108 - class_label_accuracy: 0.7999 - val_loss: 0.7124 - val_bounding_box_loss: 0.0510 - val_class_label_loss: 0.6614 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 31/200
# 26/26 [==============================] - 8s 296ms/step - loss: 0.6903 - bounding_box_loss: 0.0510 - class_label_loss: 0.6393 - bounding_box_accuracy: 0.6257 - class_label_accuracy: 0.7887 - val_loss: 0.7098 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6589 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 32/200
# 26/26 [==============================] - 8s 301ms/step - loss: 0.6686 - bounding_box_loss: 0.0522 - class_label_loss: 0.6164 - bounding_box_accuracy: 0.6279 - class_label_accuracy: 0.7872 - val_loss: 0.7104 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6596 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 33/200
# 26/26 [==============================] - 8s 300ms/step - loss: 0.6608 - bounding_box_loss: 0.0521 - class_label_loss: 0.6087 - bounding_box_accuracy: 0.6270 - class_label_accuracy: 0.8000 - val_loss: 0.7035 - val_bounding_box_loss: 0.0510 - val_class_label_loss: 0.6525 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 34/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6410 - bounding_box_loss: 0.0508 - class_label_loss: 0.5902 - bounding_box_accuracy: 0.6261 - class_label_accuracy: 0.8082 - val_loss: 0.7156 - val_bounding_box_loss: 0.0511 - val_class_label_loss: 0.6645 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 35/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6489 - bounding_box_loss: 0.0517 - class_label_loss: 0.5973 - bounding_box_accuracy: 0.6230 - class_label_accuracy: 0.8051 - val_loss: 0.7308 - val_bounding_box_loss: 0.0511 - val_class_label_loss: 0.6797 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 36/200
# 26/26 [==============================] - 8s 296ms/step - loss: 0.6313 - bounding_box_loss: 0.0503 - class_label_loss: 0.5810 - bounding_box_accuracy: 0.6317 - class_label_accuracy: 0.8110 - val_loss: 0.7263 - val_bounding_box_loss: 0.0512 - val_class_label_loss: 0.6752 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 37/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6731 - bounding_box_loss: 0.0500 - class_label_loss: 0.6232 - bounding_box_accuracy: 0.6308 - class_label_accuracy: 0.7932 - val_loss: 0.7327 - val_bounding_box_loss: 0.0517 - val_class_label_loss: 0.6809 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 38/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6588 - bounding_box_loss: 0.0513 - class_label_loss: 0.6075 - bounding_box_accuracy: 0.6276 - class_label_accuracy: 0.7957 - val_loss: 0.7290 - val_bounding_box_loss: 0.0511 - val_class_label_loss: 0.6779 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 39/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6429 - bounding_box_loss: 0.0516 - class_label_loss: 0.5913 - bounding_box_accuracy: 0.6258 - class_label_accuracy: 0.8084 - val_loss: 0.7286 - val_bounding_box_loss: 0.0510 - val_class_label_loss: 0.6775 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 40/200
# 26/26 [==============================] - 8s 297ms/step - loss: 0.6503 - bounding_box_loss: 0.0509 - class_label_loss: 0.5994 - bounding_box_accuracy: 0.6210 - class_label_accuracy: 0.7947 - val_loss: 0.7349 - val_bounding_box_loss: 0.0512 - val_class_label_loss: 0.6837 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 41/200
# 26/26 [==============================] - 8s 297ms/step - loss: 0.6424 - bounding_box_loss: 0.0517 - class_label_loss: 0.5907 - bounding_box_accuracy: 0.6156 - class_label_accuracy: 0.8072 - val_loss: 0.7397 - val_bounding_box_loss: 0.0512 - val_class_label_loss: 0.6885 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 42/200
# 26/26 [==============================] - 8s 297ms/step - loss: 0.6475 - bounding_box_loss: 0.0511 - class_label_loss: 0.5963 - bounding_box_accuracy: 0.6238 - class_label_accuracy: 0.7985 - val_loss: 0.7311 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6801 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 43/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6625 - bounding_box_loss: 0.0522 - class_label_loss: 0.6104 - bounding_box_accuracy: 0.6236 - class_label_accuracy: 0.7916 - val_loss: 0.7095 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6587 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 44/200
# 26/26 [==============================] - 8s 297ms/step - loss: 0.6640 - bounding_box_loss: 0.0506 - class_label_loss: 0.6134 - bounding_box_accuracy: 0.6319 - class_label_accuracy: 0.7917 - val_loss: 0.7122 - val_bounding_box_loss: 0.0513 - val_class_label_loss: 0.6610 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 45/200
# 26/26 [==============================] - 8s 297ms/step - loss: 0.6574 - bounding_box_loss: 0.0512 - class_label_loss: 0.6062 - bounding_box_accuracy: 0.6326 - class_label_accuracy: 0.8059 - val_loss: 0.7330 - val_bounding_box_loss: 0.0511 - val_class_label_loss: 0.6819 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 46/200
# 26/26 [==============================] - 8s 297ms/step - loss: 0.6609 - bounding_box_loss: 0.0497 - class_label_loss: 0.6112 - bounding_box_accuracy: 0.6261 - class_label_accuracy: 0.7976 - val_loss: 0.7246 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6737 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 47/200
# 26/26 [==============================] - 8s 301ms/step - loss: 0.6446 - bounding_box_loss: 0.0522 - class_label_loss: 0.5923 - bounding_box_accuracy: 0.6205 - class_label_accuracy: 0.8035 - val_loss: 0.7359 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6849 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 48/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6569 - bounding_box_loss: 0.0507 - class_label_loss: 0.6062 - bounding_box_accuracy: 0.6337 - class_label_accuracy: 0.8013 - val_loss: 0.7144 - val_bounding_box_loss: 0.0512 - val_class_label_loss: 0.6632 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 49/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6496 - bounding_box_loss: 0.0515 - class_label_loss: 0.5981 - bounding_box_accuracy: 0.6350 - class_label_accuracy: 0.7961 - val_loss: 0.7210 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6701 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 50/200
# 26/26 [==============================] - 8s 297ms/step - loss: 0.6504 - bounding_box_loss: 0.0512 - class_label_loss: 0.5992 - bounding_box_accuracy: 0.6375 - class_label_accuracy: 0.7980 - val_loss: 0.7302 - val_bounding_box_loss: 0.0511 - val_class_label_loss: 0.6791 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 51/200
# 26/26 [==============================] - 8s 301ms/step - loss: 0.6626 - bounding_box_loss: 0.0512 - class_label_loss: 0.6114 - bounding_box_accuracy: 0.6217 - class_label_accuracy: 0.7929 - val_loss: 0.7240 - val_bounding_box_loss: 0.0510 - val_class_label_loss: 0.6729 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 52/200
# 26/26 [==============================] - 8s 300ms/step - loss: 0.6477 - bounding_box_loss: 0.0510 - class_label_loss: 0.5967 - bounding_box_accuracy: 0.6449 - class_label_accuracy: 0.7968 - val_loss: 0.7387 - val_bounding_box_loss: 0.0514 - val_class_label_loss: 0.6873 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 53/200
# 26/26 [==============================] - 8s 297ms/step - loss: 0.6598 - bounding_box_loss: 0.0513 - class_label_loss: 0.6085 - bounding_box_accuracy: 0.6228 - class_label_accuracy: 0.7965 - val_loss: 0.7413 - val_bounding_box_loss: 0.0512 - val_class_label_loss: 0.6901 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 54/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6661 - bounding_box_loss: 0.0516 - class_label_loss: 0.6145 - bounding_box_accuracy: 0.6231 - class_label_accuracy: 0.7955 - val_loss: 0.7250 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6742 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 55/200
# 26/26 [==============================] - 8s 296ms/step - loss: 0.6592 - bounding_box_loss: 0.0523 - class_label_loss: 0.6069 - bounding_box_accuracy: 0.6207 - class_label_accuracy: 0.7959 - val_loss: 0.7383 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6874 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 56/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6515 - bounding_box_loss: 0.0508 - class_label_loss: 0.6006 - bounding_box_accuracy: 0.6237 - class_label_accuracy: 0.7979 - val_loss: 0.7226 - val_bounding_box_loss: 0.0510 - val_class_label_loss: 0.6715 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 57/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6415 - bounding_box_loss: 0.0517 - class_label_loss: 0.5898 - bounding_box_accuracy: 0.6302 - class_label_accuracy: 0.8019 - val_loss: 0.7485 - val_bounding_box_loss: 0.0512 - val_class_label_loss: 0.6973 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 58/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6572 - bounding_box_loss: 0.0524 - class_label_loss: 0.6048 - bounding_box_accuracy: 0.6256 - class_label_accuracy: 0.7945 - val_loss: 0.7490 - val_bounding_box_loss: 0.0510 - val_class_label_loss: 0.6981 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 59/200
# 26/26 [==============================] - 8s 296ms/step - loss: 0.6376 - bounding_box_loss: 0.0520 - class_label_loss: 0.5857 - bounding_box_accuracy: 0.6240 - class_label_accuracy: 0.8029 - val_loss: 0.7348 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6840 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 60/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6449 - bounding_box_loss: 0.0511 - class_label_loss: 0.5938 - bounding_box_accuracy: 0.6248 - class_label_accuracy: 0.8011 - val_loss: 0.7314 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6805 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 61/200
# 26/26 [==============================] - 8s 297ms/step - loss: 0.6474 - bounding_box_loss: 0.0508 - class_label_loss: 0.5966 - bounding_box_accuracy: 0.6182 - class_label_accuracy: 0.7977 - val_loss: 0.7333 - val_bounding_box_loss: 0.0510 - val_class_label_loss: 0.6823 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 62/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6635 - bounding_box_loss: 0.0517 - class_label_loss: 0.6119 - bounding_box_accuracy: 0.6260 - class_label_accuracy: 0.7905 - val_loss: 0.7269 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6761 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 63/200
# 26/26 [==============================] - 8s 297ms/step - loss: 0.6395 - bounding_box_loss: 0.0514 - class_label_loss: 0.5880 - bounding_box_accuracy: 0.6297 - class_label_accuracy: 0.8055 - val_loss: 0.7197 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6687 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 64/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6571 - bounding_box_loss: 0.0508 - class_label_loss: 0.6063 - bounding_box_accuracy: 0.6363 - class_label_accuracy: 0.7970 - val_loss: 0.7257 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6750 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 65/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6488 - bounding_box_loss: 0.0518 - class_label_loss: 0.5970 - bounding_box_accuracy: 0.6282 - class_label_accuracy: 0.8006 - val_loss: 0.7184 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6675 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 66/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6491 - bounding_box_loss: 0.0519 - class_label_loss: 0.5971 - bounding_box_accuracy: 0.6226 - class_label_accuracy: 0.7993 - val_loss: 0.7322 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6814 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 67/200
# 26/26 [==============================] - 8s 300ms/step - loss: 0.6607 - bounding_box_loss: 0.0505 - class_label_loss: 0.6101 - bounding_box_accuracy: 0.6204 - class_label_accuracy: 0.7966 - val_loss: 0.7123 - val_bounding_box_loss: 0.0510 - val_class_label_loss: 0.6613 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 68/200
# 26/26 [==============================] - 8s 296ms/step - loss: 0.6553 - bounding_box_loss: 0.0518 - class_label_loss: 0.6035 - bounding_box_accuracy: 0.6336 - class_label_accuracy: 0.8011 - val_loss: 0.7239 - val_bounding_box_loss: 0.0510 - val_class_label_loss: 0.6729 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 69/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6397 - bounding_box_loss: 0.0507 - class_label_loss: 0.5890 - bounding_box_accuracy: 0.6323 - class_label_accuracy: 0.7986 - val_loss: 0.7314 - val_bounding_box_loss: 0.0510 - val_class_label_loss: 0.6804 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 70/200
# 26/26 [==============================] - 8s 295ms/step - loss: 0.6278 - bounding_box_loss: 0.0514 - class_label_loss: 0.5764 - bounding_box_accuracy: 0.6312 - class_label_accuracy: 0.8057 - val_loss: 0.7260 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6751 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 71/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6855 - bounding_box_loss: 0.0516 - class_label_loss: 0.6339 - bounding_box_accuracy: 0.6220 - class_label_accuracy: 0.7783 - val_loss: 0.7096 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6587 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 72/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6500 - bounding_box_loss: 0.0502 - class_label_loss: 0.5998 - bounding_box_accuracy: 0.6130 - class_label_accuracy: 0.7995 - val_loss: 0.7202 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6694 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 73/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6536 - bounding_box_loss: 0.0514 - class_label_loss: 0.6022 - bounding_box_accuracy: 0.6329 - class_label_accuracy: 0.7960 - val_loss: 0.7172 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6664 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 74/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6474 - bounding_box_loss: 0.0520 - class_label_loss: 0.5954 - bounding_box_accuracy: 0.6198 - class_label_accuracy: 0.8036 - val_loss: 0.7243 - val_bounding_box_loss: 0.0510 - val_class_label_loss: 0.6733 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 75/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6392 - bounding_box_loss: 0.0511 - class_label_loss: 0.5880 - bounding_box_accuracy: 0.6309 - class_label_accuracy: 0.7989 - val_loss: 0.7090 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6582 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 76/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6666 - bounding_box_loss: 0.0526 - class_label_loss: 0.6140 - bounding_box_accuracy: 0.6197 - class_label_accuracy: 0.7896 - val_loss: 0.7265 - val_bounding_box_loss: 0.0510 - val_class_label_loss: 0.6756 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 77/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6443 - bounding_box_loss: 0.0520 - class_label_loss: 0.5923 - bounding_box_accuracy: 0.6332 - class_label_accuracy: 0.7991 - val_loss: 0.7161 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6653 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 78/200
# 26/26 [==============================] - 8s 300ms/step - loss: 0.6550 - bounding_box_loss: 0.0511 - class_label_loss: 0.6039 - bounding_box_accuracy: 0.6170 - class_label_accuracy: 0.7966 - val_loss: 0.7241 - val_bounding_box_loss: 0.0512 - val_class_label_loss: 0.6729 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 79/200
# 26/26 [==============================] - 8s 301ms/step - loss: 0.6353 - bounding_box_loss: 0.0520 - class_label_loss: 0.5832 - bounding_box_accuracy: 0.6309 - class_label_accuracy: 0.8035 - val_loss: 0.7307 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6798 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 80/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6697 - bounding_box_loss: 0.0523 - class_label_loss: 0.6174 - bounding_box_accuracy: 0.6365 - class_label_accuracy: 0.7919 - val_loss: 0.7157 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6648 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 81/200
# 26/26 [==============================] - 8s 300ms/step - loss: 0.6407 - bounding_box_loss: 0.0510 - class_label_loss: 0.5898 - bounding_box_accuracy: 0.6227 - class_label_accuracy: 0.8026 - val_loss: 0.7184 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6676 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 82/200
# 26/26 [==============================] - 8s 296ms/step - loss: 0.6261 - bounding_box_loss: 0.0510 - class_label_loss: 0.5751 - bounding_box_accuracy: 0.6282 - class_label_accuracy: 0.8135 - val_loss: 0.7176 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6668 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 83/200
# 26/26 [==============================] - 8s 297ms/step - loss: 0.6610 - bounding_box_loss: 0.0513 - class_label_loss: 0.6097 - bounding_box_accuracy: 0.6282 - class_label_accuracy: 0.7918 - val_loss: 0.7195 - val_bounding_box_loss: 0.0510 - val_class_label_loss: 0.6685 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 84/200
# 26/26 [==============================] - 8s 300ms/step - loss: 0.6475 - bounding_box_loss: 0.0508 - class_label_loss: 0.5968 - bounding_box_accuracy: 0.6299 - class_label_accuracy: 0.8027 - val_loss: 0.7250 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6742 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 85/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6587 - bounding_box_loss: 0.0502 - class_label_loss: 0.6085 - bounding_box_accuracy: 0.6436 - class_label_accuracy: 0.7945 - val_loss: 0.7223 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6715 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 86/200
# 26/26 [==============================] - 8s 296ms/step - loss: 0.6643 - bounding_box_loss: 0.0512 - class_label_loss: 0.6131 - bounding_box_accuracy: 0.6228 - class_label_accuracy: 0.7942 - val_loss: 0.7165 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6656 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 87/200
# 26/26 [==============================] - 8s 301ms/step - loss: 0.6518 - bounding_box_loss: 0.0515 - class_label_loss: 0.6002 - bounding_box_accuracy: 0.6245 - class_label_accuracy: 0.7982 - val_loss: 0.7226 - val_bounding_box_loss: 0.0510 - val_class_label_loss: 0.6716 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 88/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6497 - bounding_box_loss: 0.0517 - class_label_loss: 0.5980 - bounding_box_accuracy: 0.6184 - class_label_accuracy: 0.7970 - val_loss: 0.7302 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6793 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 89/200
# 26/26 [==============================] - 8s 300ms/step - loss: 0.6097 - bounding_box_loss: 0.0511 - class_label_loss: 0.5586 - bounding_box_accuracy: 0.6165 - class_label_accuracy: 0.8103 - val_loss: 0.7347 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6837 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 90/200
# 26/26 [==============================] - 8s 300ms/step - loss: 0.6531 - bounding_box_loss: 0.0498 - class_label_loss: 0.6033 - bounding_box_accuracy: 0.6284 - class_label_accuracy: 0.7977 - val_loss: 0.7284 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6775 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 91/200
# 26/26 [==============================] - 8s 297ms/step - loss: 0.6434 - bounding_box_loss: 0.0509 - class_label_loss: 0.5926 - bounding_box_accuracy: 0.6224 - class_label_accuracy: 0.7976 - val_loss: 0.7260 - val_bounding_box_loss: 0.0511 - val_class_label_loss: 0.6749 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 92/200
# 26/26 [==============================] - 8s 300ms/step - loss: 0.6555 - bounding_box_loss: 0.0510 - class_label_loss: 0.6045 - bounding_box_accuracy: 0.6224 - class_label_accuracy: 0.7959 - val_loss: 0.7254 - val_bounding_box_loss: 0.0511 - val_class_label_loss: 0.6743 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 93/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6432 - bounding_box_loss: 0.0502 - class_label_loss: 0.5929 - bounding_box_accuracy: 0.6281 - class_label_accuracy: 0.8005 - val_loss: 0.7292 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6784 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 94/200
# 26/26 [==============================] - 8s 300ms/step - loss: 0.6456 - bounding_box_loss: 0.0508 - class_label_loss: 0.5948 - bounding_box_accuracy: 0.6309 - class_label_accuracy: 0.7973 - val_loss: 0.7265 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6756 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 95/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6220 - bounding_box_loss: 0.0509 - class_label_loss: 0.5711 - bounding_box_accuracy: 0.6320 - class_label_accuracy: 0.8091 - val_loss: 0.7475 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6967 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 96/200
# 26/26 [==============================] - 8s 300ms/step - loss: 0.6412 - bounding_box_loss: 0.0510 - class_label_loss: 0.5902 - bounding_box_accuracy: 0.6264 - class_label_accuracy: 0.7975 - val_loss: 0.7301 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6793 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 97/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6462 - bounding_box_loss: 0.0508 - class_label_loss: 0.5954 - bounding_box_accuracy: 0.6359 - class_label_accuracy: 0.7975 - val_loss: 0.7221 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6713 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 98/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6577 - bounding_box_loss: 0.0516 - class_label_loss: 0.6062 - bounding_box_accuracy: 0.6202 - class_label_accuracy: 0.7931 - val_loss: 0.7188 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6679 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 99/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6221 - bounding_box_loss: 0.0499 - class_label_loss: 0.5722 - bounding_box_accuracy: 0.6315 - class_label_accuracy: 0.8101 - val_loss: 0.7229 - val_bounding_box_loss: 0.0510 - val_class_label_loss: 0.6720 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 100/200
# 26/26 [==============================] - 8s 302ms/step - loss: 0.6283 - bounding_box_loss: 0.0503 - class_label_loss: 0.5779 - bounding_box_accuracy: 0.6319 - class_label_accuracy: 0.8088 - val_loss: 0.7329 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6820 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 101/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6323 - bounding_box_loss: 0.0510 - class_label_loss: 0.5814 - bounding_box_accuracy: 0.6180 - class_label_accuracy: 0.8072 - val_loss: 0.7316 - val_bounding_box_loss: 0.0513 - val_class_label_loss: 0.6802 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 102/200
# 26/26 [==============================] - 8s 300ms/step - loss: 0.6385 - bounding_box_loss: 0.0517 - class_label_loss: 0.5868 - bounding_box_accuracy: 0.6294 - class_label_accuracy: 0.7999 - val_loss: 0.7231 - val_bounding_box_loss: 0.0513 - val_class_label_loss: 0.6718 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 103/200
# 26/26 [==============================] - 8s 300ms/step - loss: 0.6556 - bounding_box_loss: 0.0518 - class_label_loss: 0.6037 - bounding_box_accuracy: 0.6333 - class_label_accuracy: 0.7917 - val_loss: 0.7218 - val_bounding_box_loss: 0.0511 - val_class_label_loss: 0.6708 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 104/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6523 - bounding_box_loss: 0.0504 - class_label_loss: 0.6019 - bounding_box_accuracy: 0.6321 - class_label_accuracy: 0.7943 - val_loss: 0.7134 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6625 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 105/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6483 - bounding_box_loss: 0.0512 - class_label_loss: 0.5971 - bounding_box_accuracy: 0.6201 - class_label_accuracy: 0.7954 - val_loss: 0.7308 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6799 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 106/200
# 26/26 [==============================] - 8s 301ms/step - loss: 0.6540 - bounding_box_loss: 0.0516 - class_label_loss: 0.6024 - bounding_box_accuracy: 0.6329 - class_label_accuracy: 0.7975 - val_loss: 0.7202 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6694 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 107/200
# 26/26 [==============================] - 8s 298ms/step - loss: 0.6562 - bounding_box_loss: 0.0517 - class_label_loss: 0.6045 - bounding_box_accuracy: 0.6270 - class_label_accuracy: 0.7936 - val_loss: 0.7195 - val_bounding_box_loss: 0.0510 - val_class_label_loss: 0.6685 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 108/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6569 - bounding_box_loss: 0.0513 - class_label_loss: 0.6056 - bounding_box_accuracy: 0.6204 - class_label_accuracy: 0.7942 - val_loss: 0.7299 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6791 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 109/200
# 26/26 [==============================] - 8s 296ms/step - loss: 0.6349 - bounding_box_loss: 0.0504 - class_label_loss: 0.5844 - bounding_box_accuracy: 0.6278 - class_label_accuracy: 0.8025 - val_loss: 0.7267 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6759 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 110/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6333 - bounding_box_loss: 0.0506 - class_label_loss: 0.5827 - bounding_box_accuracy: 0.6359 - class_label_accuracy: 0.8018 - val_loss: 0.7359 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6851 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 111/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6564 - bounding_box_loss: 0.0509 - class_label_loss: 0.6055 - bounding_box_accuracy: 0.6390 - class_label_accuracy: 0.7908 - val_loss: 0.7177 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6668 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 112/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6296 - bounding_box_loss: 0.0511 - class_label_loss: 0.5786 - bounding_box_accuracy: 0.6231 - class_label_accuracy: 0.8056 - val_loss: 0.7290 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6781 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 113/200
# 26/26 [==============================] - 8s 301ms/step - loss: 0.6325 - bounding_box_loss: 0.0515 - class_label_loss: 0.5809 - bounding_box_accuracy: 0.6138 - class_label_accuracy: 0.8115 - val_loss: 0.7193 - val_bounding_box_loss: 0.0510 - val_class_label_loss: 0.6682 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 114/200
# 26/26 [==============================] - 8s 299ms/step - loss: 0.6345 - bounding_box_loss: 0.0498 - class_label_loss: 0.5847 - bounding_box_accuracy: 0.6287 - class_label_accuracy: 0.8022 - val_loss: 0.7225 - val_bounding_box_loss: 0.0508 - val_class_label_loss: 0.6717 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 115/200
# 26/26 [==============================] - 8s 296ms/step - loss: 0.6362 - bounding_box_loss: 0.0509 - class_label_loss: 0.5853 - bounding_box_accuracy: 0.6175 - class_label_accuracy: 0.7986 - val_loss: 0.7226 - val_bounding_box_loss: 0.0509 - val_class_label_loss: 0.6717 - val_bounding_box_accuracy: 0.6196 - val_class_label_accuracy: 0.7718
# Epoch 116/200
# 20/26 [======================>.......] - ETA: 1s - loss: 0.6416 - bounding_box_loss: 0.0512 - class_label_loss: 0.5905 - bounding_box_accuracy: 0.6270 - class_label_accuracy: 0.8007
